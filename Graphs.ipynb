# %% [markdown]
# # Load the data analysis libraries

# %%
import numpy as np #for numbers
import matplotlib.pyplot as plt #for graphs

# %% [markdown]
# Get the data/generate data

# %%
rainfall=[67,20,10,10,10,26]
months=['jan','feb','mar','apr','may','jun']

# %% [markdown]
# Visualize the data

# %%
plt.style.available

# %%
plt.style.use('ggplot')

# %%
plt.bar(months,rainfall,color='#1f77b4')

# %%
# f=minimum 6 characters
# 0.1 ans upto 1 decimal point
plt.pie(
    rainfall,
    labels=months,
    autopct='%.1f%%',
)
plt.show()

# %%
plt.pie(
    rainfall,
    labels=months,
    autopct='%.1f%%',
    wedgeprops={'width':0.4},
    pctdistance=.8
)
plt.show()

# %%
plt.pie(
    rainfall,
    labels=months,
    autopct='%.1f%%',
    wedgeprops={'width':0.4, 'edgecolor': '#6666ff', 'linewidth':2},
    pctdistance=.8
)
plt.show()

# %%
plt.boxplot(rainfall,
            vert=False,
            showmeans=True,
            meanline=True,
            meanprops={'color':'red'}
            )            
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,4))  # Create a figure containing a single axes. 
ax.plot([1, 2, 3, 4], [1, 4, 2, 3], label='kuch bhi')  # Plot some data on the axes.
ax.grid()
ax.legend()

# %%
fig, ax = plt.subplots(figsize=(5,4)) 
ax.plot([1, 2, 3, 4], [1, 4, 2, 3], label='kuch bhi')  
ax.plot([1, 2, 3, 4], [2, 3, 4, 1], label='kuch bhi nahi')  
ax.grid()
ax.legend()

# %%
t= np.arange(-10,10,.2)
t
print(t.size)

# %%
t= np.arange(-10,10,.2)
y=np.sin(t)
fig, ax= plt.subplots(figsize=(10,3))
ax.plot(t,y,label='sin wave')
ax.grid()
ax.legend()
ax.set_xlabel('time')
ax.set_ylabel('amplitude')

# %%
t= np.arange(-10,10,.2)
y=np.sin(t)
fig, ax= plt.subplots(figsize=(10,3))
ax.plot(t,y,label='sin wave', color='blue', linestyle='-',linewidth=2,marker='*',markersize=6,markerfacecolor='black',alpha=.5)
ax.legend()
ax.set_xlabel('time')
ax.set_ylabel('amplitude')
# Out:
# Text(0, 0.5, 'amplitude')

# %%
t= np.arange(-10,10,.2)
y=np.cos(t)
fig, ax= plt.subplots(figsize=(10,3))
ax.plot(t,y,label='cos wave', color='blue', linestyle='-',linewidth=2,marker='*',markersize=6,markerfacecolor='black',alpha=.5)
ax.legend()
ax.set_xlabel('time')
ax.set_ylabel('amplitude')
# Out:
# Text(0, 0.5, 'amplitude')

# %%
t= np.arange(-10,10,.2)
y=np.sin(t)
y2=np.cos(t)
fig, ax= plt.subplots(figsize=(10,3))
ax.plot(t,y,label='sin wave', color='blue', linestyle='-',linewidth=2,marker='*',markersize=6,markerfacecolor='black',alpha=.8)
ax.plot(t,y2,label='cosin wave', color='green', linestyle='-',linewidth=2,marker='*',markersize=6,markerfacecolor='red',alpha=.8)
ax.legend()
ax.set_xlabel('time')
ax.set_ylabel('amplitude')
# Out:
# Text(0, 0.5, 'amplitude')

# %%
t= np.arange(-10,10,.2)
y=np.sin(t)
y2=np.tan(t)
fig, ax= plt.subplots(figsize=(10,3))
ax.plot(t,y,label='sin wave', color='blue', linestyle='-',linewidth=2,marker='*',markersize=6,markerfacecolor='black',alpha=.8)
ax.plot(t,y2,label='tan wave', color='green', linestyle='-',linewidth=2,marker='*',markersize=6,markerfacecolor='red',alpha=.8)
ax.legend()
ax.set_xlabel('time')
ax.set_ylabel('amplitude')
# Out:
# Text(0, 0.5, 'amplitude')

# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np

# %%
fig, ax = plt.subplots()
t = np.linspace(0, 3, 40)
g = -9.81
v0 = 12
z = g * t**2 / 2 + v0 * t

v02 = 5
z2 = g * t**2 / 2 + v02 * t

scat = ax.scatter(t[0], z[0], c="b", s=5, label=f'v0 = {v0} m/s')
line2 = ax.plot(t[0], z2[0], label=f'v0 = {v02} m/s')[0]
ax.set(xlim=[0, 3], ylim=[-4, 10], xlabel='Time [s]', ylabel='Z [m]')
ax.legend()


def update(frame):
    # for each frame, update the data stored on each artist.
    x = t[:frame]
    y = z[:frame]
    # update the scatter plot:
    data = np.stack([x, y]).T
    scat.set_offsets(data)
    # update the line plot:
    line2.set_xdata(t[:frame])
    line2.set_ydata(z2[:frame])
    return (scat, line2)


ani = animation.FuncAnimation(fig=fig, func=update, frames=40, interval=30)
plt.show()
